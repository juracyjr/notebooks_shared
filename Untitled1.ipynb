# %%
import pandas as pd
import folium

# %%
df = pd.read_csv("/dados/isc/erika_pau_da_lima_ubs/ubs_pontos_geo.csv",sep=";")

# %%
df
# Out:
#                                      nome  \
# 0                           UBS CANABRAVA
# 1          UBS CASTELO BRANCO (20º C.S.)
# 2                        UBS CECY ANDRADE
# 3                          USF Dom Avelar
# 4              UBS EDGARD PIRES DA VEIGA
# 5                       USF Nova Brasília
# 6               USF NOVA BRASÍLIA (ANEXO)
# 7                      UBS SETE DE ABRIL
# 8                           USF Canabrava
# 9                    USF VALE DO CAMBONAS
# 10                     UBS VALE DOS LAGOS
# 11                         USF SÃO MARCOS
# 12                    USF JOÃO ROMA FILHO
# 13                     UBS NOVO MAROTINHO
# 14                       CAPS PAU DA LIMA
# 15                        P.A. SÃO MARCOS
# 16  CCVP- Complexo Comunitário Vida Plena
# 17                      Mansão do Caminho
#
#                                              endereco        lat       long  \
# 0   R. Bem-Te-VI, 88-42 - Canabrava, Salvador - BA... -12.923483 -38.418930
# 1                 Rua A, 3º Etapa, s/n Castelo Branco -12.901669 -38.427298
# 2   Rua Genaro De Carvalho sn 1 Etapa - Castelo Br... -12.907994 -38.444910
# 3    S/N, R. das Paulinas - Dom Avelar, Salvador - BA -12.903851 -38.449685
# 4     Rua Jayme Vieira Lima, Salvador - BA, 41235-000 -12.919918 -38.442947
# 5   Av. Aliomar Baleeiro - Nova Brasília, Salvador... -12.918652 -38.408420
# 6                                                 NaN        NaN        NaN
# 7   R. Felícia, sn - Sete de Abril, Salvador - BA,... -12.909814 -38.425416
# 8   R. Artêmio Castro Valente, sn - Canabrava, Sal... -12.925523 -38.416986
# 9   Via Regional sn, R. Nova de 7 de Abril - Sete ... -12.908908 -38.421763
# 10                                                NaN -12.934121 -38.419310
# 11  Prox. Ao Cmei - R. Djalma Sanches, sn - São Ma... -12.925116 -38.435563
# 12  Av. Aliomar Baleeiro, SN - Jardim Nova Esperan... -12.918667 -38.407892
# 13  Av. Aliomar Baleeiro, s/n - Novo Marotinho, Sa... -12.915997 -38.426388
# 14  R. Dom Bôsco, 57-1 - São Marcos, Salvador - BA... -12.934866 -38.417990
# 15  R. do Campo de Sussuarana, 18 - Sussuarana, Sa... -12.938237 -38.437783
# 16  Rua Dr. Arthur Gonzales, 186 - Pau da Lima, Sa... -12.922509 -38.445346
# 17  Rua Jayme Vieira Lima, 104 - São Marcos, Salva... -12.916039 -38.443739
#
#      tipo
# 0     UBS
# 1     UBS
# 2     UBS
# 3     USF
# 4     UBS
# 5     USF
# 6     NaN
# 7     UBS
# 8     USF
# 9     USF
# 10    UBS
# 11    USF
# 12    USF
# 13    UBS
# 14   CAPS
# 15     PA
# 16   CCVP
# 17  outro

# %%
df_ok = df.dropna(axis=0, how='any')

# %%
df_ok
# Out:
#                                      nome  \
# 0                           UBS CANABRAVA
# 1          UBS CASTELO BRANCO (20º C.S.)
# 2                        UBS CECY ANDRADE
# 3                          USF Dom Avelar
# 4              UBS EDGARD PIRES DA VEIGA
# 5                       USF Nova Brasília
# 7                      UBS SETE DE ABRIL
# 8                           USF Canabrava
# 9                    USF VALE DO CAMBONAS
# 11                         USF SÃO MARCOS
# 12                    USF JOÃO ROMA FILHO
# 13                     UBS NOVO MAROTINHO
# 14                       CAPS PAU DA LIMA
# 15                        P.A. SÃO MARCOS
# 16  CCVP- Complexo Comunitário Vida Plena
# 17                      Mansão do Caminho
#
#                                              endereco        lat       long  \
# 0   R. Bem-Te-VI, 88-42 - Canabrava, Salvador - BA... -12.923483 -38.418930
# 1                 Rua A, 3º Etapa, s/n Castelo Branco -12.901669 -38.427298
# 2   Rua Genaro De Carvalho sn 1 Etapa - Castelo Br... -12.907994 -38.444910
# 3    S/N, R. das Paulinas - Dom Avelar, Salvador - BA -12.903851 -38.449685
# 4     Rua Jayme Vieira Lima, Salvador - BA, 41235-000 -12.919918 -38.442947
# 5   Av. Aliomar Baleeiro - Nova Brasília, Salvador... -12.918652 -38.408420
# 7   R. Felícia, sn - Sete de Abril, Salvador - BA,... -12.909814 -38.425416
# 8   R. Artêmio Castro Valente, sn - Canabrava, Sal... -12.925523 -38.416986
# 9   Via Regional sn, R. Nova de 7 de Abril - Sete ... -12.908908 -38.421763
# 11  Prox. Ao Cmei - R. Djalma Sanches, sn - São Ma... -12.925116 -38.435563
# 12  Av. Aliomar Baleeiro, SN - Jardim Nova Esperan... -12.918667 -38.407892
# 13  Av. Aliomar Baleeiro, s/n - Novo Marotinho, Sa... -12.915997 -38.426388
# 14  R. Dom Bôsco, 57-1 - São Marcos, Salvador - BA... -12.934866 -38.417990
# 15  R. do Campo de Sussuarana, 18 - Sussuarana, Sa... -12.938237 -38.437783
# 16  Rua Dr. Arthur Gonzales, 186 - Pau da Lima, Sa... -12.922509 -38.445346
# 17  Rua Jayme Vieira Lima, 104 - São Marcos, Salva... -12.916039 -38.443739
#
#      tipo
# 0     UBS
# 1     UBS
# 2     UBS
# 3     USF
# 4     UBS
# 5     USF
# 7     UBS
# 8     USF
# 9     USF
# 11    USF
# 12    USF
# 13    UBS
# 14   CAPS
# 15     PA
# 16   CCVP
# 17  outro

# %%
m = folium.Map(
    location=[-12.934866, -38.443739],
    zoom_start=13
)

def func_gerar_markers(row):
    if row['tipo'] == "UBS":
        folium.Marker(
            location=[row['lat'], row['long']],
            popup=row['nome'],
            icon=folium.Icon(color='green')
        ).add_to(m)
    elif row['tipo'] == "USF":
        folium.Marker(
            location=[row['lat'], row['long']],
            popup=row['nome'],
            icon=folium.Icon(color='red')
        ).add_to(m)
    else:
        folium.Marker(
            location=[row['lat'], row['long']],
            popup=row['nome'],
            icon=folium.Icon(color='blue')
        ).add_to(m)

df_ok.apply(func_gerar_markers,axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 7     None
# 8     None
# 9     None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# dtype: object

# %%
#m

# %%
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 50px; left: 50px; width: 100px; height: 90px; 
                            border:2px solid grey; z-index:9999; font-size:14px;
                            ">&nbsp;Legenda <br>
                              &nbsp; UBS &nbsp; <i class="fa fa-map-marker fa-1x" style="color:green"></i><br>
                              &nbsp; USF &nbsp; <i class="fa fa-map-marker fa-1x" style="color:red"></i><br>
                              &nbsp; Outros &nbsp; <i class="fa fa-map-marker fa-1x" style="color:blue"></i>
                </div>
                ''' 

m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
